# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
plt.style.use(['classic', 'ggplot'])

# %%
D = pd.read_csv('D_cols.csv') 
ifd = pd.read_csv('N_cols.csv')

# %%
D = D.merge(ifd[['isFraud']], left_index=True, right_index=True)

# %%
import seaborn as sns

import matplotlib.pyplot as plt
def plot_box(df, feature):
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    
    sns.boxplot(x='isFraud', y=feature, data=df, ax=axes[0])
    axes[0].set_title(f'Boxplot of {feature} by isFraud')
    
    sns.boxplot(x='isFraud', y=feature, data=df, ax=axes[1])
    sns.stripplot(x='isFraud', y=feature, data=df, color='yellow', size=4, jitter=0.2, ax=axes[1])
    axes[1].set_title(f'Boxplot with IDs plot of {feature} by isFraud')
    
    sns.distplot(df[df['isFraud'] == 0][feature], kde=True, color='blue', label='Not Fraud', ax=axes[2])
    sns.distplot(df[df['isFraud'] == 1][feature], kde=True, color='red', label='Fraud', ax=axes[2])
    axes[2].set_title(f'Histogram of {feature} by isFraud')
    axes[2].legend()
    
    plt.tight_layout()
    plt.show()

# %%
D.describe()
# Out:
#          Unnamed: 0            D1             D2             D3  \
# count  1.097231e+06  1.089931e+06  581665.000000  631211.000000
# mean   2.759092e+05  1.007141e+02     178.493856      30.772553
# std    1.611145e+05  1.669482e+02     187.068316      72.831084
# min    0.000000e+00  0.000000e+00       0.000000       0.000000
# 25%    1.371535e+05  0.000000e+00      26.000000       1.000000
# 50%    2.743070e+05  4.000000e+00     104.000000       8.000000
# 75%    4.114610e+05  1.330000e+02     290.000000      27.000000
# max    5.905390e+05  6.410000e+02     641.000000    1076.000000
#
#                   D4             D5             D6            D7  \
# count  851458.000000  563015.000000  197970.000000  99050.000000
# mean      157.700888      46.669268      77.771248     53.888168
# std       223.712055     103.980714     176.391818    133.117045
# min      -122.000000       0.000000     -83.000000      0.000000
# 25%         0.000000       1.000000       0.000000      0.000000
# 50%        23.000000       9.000000       0.000000      0.000000
# 75%       272.000000      33.000000      21.000000     18.000000
# max      1091.000000    1088.000000    1091.000000   1088.000000
#
#                   D8             D9           D10            D11  \
# count  149264.000000  149264.000000  1.008664e+06  641426.000000
# mean      153.422328       0.557532  1.415345e+02     183.577017
# std       244.736950       0.317129  2.137367e+02     225.954099
# min         0.000000       0.000000  0.000000e+00     -53.000000
# 25%         1.000000       0.208400  0.000000e+00       0.000000
# 50%        37.780000       0.666500  1.300000e+01      69.000000
# 75%       201.100000       0.833500  2.240000e+02     333.000000
# max      2030.000000       0.958500  1.091000e+03     883.000000
#
#                  D12            D13            D14            D15  \
# count  133971.000000  185336.000000  177381.000000  996049.000000
# mean       66.116518      18.117435      58.009370     185.152096
# std       153.782459      74.744808     154.868172     239.163890
# min       -83.000000       0.000000    -193.000000     -83.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000      50.000000
# 75%        18.000000       0.000000       0.000000     341.000000
# max       879.000000    1066.000000    1085.000000    1091.000000
#
#              isFraud
# count  590540.000000
# mean        0.034990
# std         0.183755
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
D['D1'].value_counts()
# Out:
# D1
# 0.0      507854
# 1.0       16887
# 2.0        9974
# 3.0        8038
# 4.0        6965
#           ...
# 557.0       278
# 593.0       276
# 591.0       273
# 640.0        67
# 641.0         1
# Name: count, Length: 642, dtype: int64

# %%
plot_box(D, 'D1')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 0][feature], kde=True, color='blue', label='Not Fraud', ax=axes[2])
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 1][feature], kde=True, color='red', label='Fraud', ax=axes[2])

# %%
plot_box(D, 'D2')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 0][feature], kde=True, color='blue', label='Not Fraud', ax=axes[2])
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 1][feature], kde=True, color='red', label='Fraud', ax=axes[2])

# %%
plot_box(D, 'D3')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 0][feature], kde=True, color='blue', label='Not Fraud', ax=axes[2])
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 1][feature], kde=True, color='red', label='Fraud', ax=axes[2])

# %%
plot_box(D, 'D4')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 0][feature], kde=True, color='blue', label='Not Fraud', ax=axes[2])
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 1][feature], kde=True, color='red', label='Fraud', ax=axes[2])

# %%
plot_box(D, 'D5')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 0][feature], kde=True, color='blue', label='Not Fraud', ax=axes[2])
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 1][feature], kde=True, color='red', label='Fraud', ax=axes[2])

# %%
plot_box(D, 'D6')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 0][feature], kde=True, color='blue', label='Not Fraud', ax=axes[2])
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 1][feature], kde=True, color='red', label='Fraud', ax=axes[2])

# %%
plot_box(D, 'D7')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 0][feature], kde=True, color='blue', label='Not Fraud', ax=axes[2])
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 1][feature], kde=True, color='red', label='Fraud', ax=axes[2])

# %%
plot_box(D, 'D8')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 0][feature], kde=True, color='blue', label='Not Fraud', ax=axes[2])
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 1][feature], kde=True, color='red', label='Fraud', ax=axes[2])

# %%
plot_box(D, 'D9')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 0][feature], kde=True, color='blue', label='Not Fraud', ax=axes[2])
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 1][feature], kde=True, color='red', label='Fraud', ax=axes[2])

# %%
plot_box(D, 'D10')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 0][feature], kde=True, color='blue', label='Not Fraud', ax=axes[2])
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 1][feature], kde=True, color='red', label='Fraud', ax=axes[2])

# %%
plot_box(D, 'D11')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 0][feature], kde=True, color='blue', label='Not Fraud', ax=axes[2])
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 1][feature], kde=True, color='red', label='Fraud', ax=axes[2])

# %%
plot_box(D, 'D12')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 0][feature], kde=True, color='blue', label='Not Fraud', ax=axes[2])
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 1][feature], kde=True, color='red', label='Fraud', ax=axes[2])

# %%
plot_box(D, 'D13')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 0][feature], kde=True, color='blue', label='Not Fraud', ax=axes[2])
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 1][feature], kde=True, color='red', label='Fraud', ax=axes[2])

# %%
plot_box(D, 'D14')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 0][feature], kde=True, color='blue', label='Not Fraud', ax=axes[2])
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 1][feature], kde=True, color='red', label='Fraud', ax=axes[2])

# %%
plot_box(D, 'D15')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 0][feature], kde=True, color='blue', label='Not Fraud', ax=axes[2])
# C:\Users\USER\AppData\Local\Temp\ipykernel_2080\3904941801.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['isFraud'] == 1][feature], kde=True, color='red', label='Fraud', ax=axes[2])
